# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatema2525/skills-introduction-to-github/blob/main/News_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
import numpy as np
import nltk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from nltk.stem import PorterStemmer

# %%
news=pd.read_csv('/content/NEWS.csv')
news.head()
# Out:
#    Unnamed: 0  ... label
# 0           0  ...     1
# 1           1  ...     1
# 2           2  ...     1
# 3           3  ...     0
# 4           4  ...     1
#
# [5 rows x 4 columns]

# %%
X=news['title'].astype(str).tolist()
Y=news['label'].values

# %%
stemmer=PorterStemmer()

# %%
def stem_text(text):
  text=text.lower()
  text=re.sub(r'[^a-z0-9\s]','',text)
  words=text.split()
  return [stemmer.stem(word) for word in words]

# %%
X=[doc for doc in X if doc.strip()!=""]

# %%
vectorizer=TfidfVectorizer(stop_words='english')
Z=vectorizer.fit_transform(X)
print(Z)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 618070 stored elements and shape (72134, 30859)>
#   Coords	Values
#   (0, 15304)	0.19718695178320336
#   (0, 9190)	0.2820931931023994
#   (0, 12692)	0.22510516475455616
#   (0, 1315)	0.2691527548469089
#   (0, 10685)	0.27336848639594746
#   (0, 26715)	0.25157459347044175
#   (0, 6200)	0.23339908357710218
#   (0, 29175)	0.30000769249666887
#   (0, 68)	0.40695686879251053
#   (0, 3296)	0.28056452465543114
#   (0, 11140)	0.40695686879251053
#   (0, 26568)	0.23248945348098574
#   (0, 28506)	0.10922343162080177
#   (1, 17772)	1.0
#   (2, 28506)	0.12943593974885745
#   (2, 27685)	0.354514908455494
#   (2, 18393)	0.16203226738187637
#   (2, 2256)	0.2744621796840378
#   (2, 11345)	0.26298800222668844
#   (2, 23310)	0.16215451438729567
#   (2, 4899)	0.3489117636482383
#   (2, 22633)	0.3447537850210061
#   (2, 19450)	0.33131915377479915
#   (2, 20838)	0.2576962071138142
#   (2, 12873)	0.26459767238287196
#   :	:
# ...

# %%
Z_train,Z_test,Y_train,Y_test=train_test_split(Z,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression()
model.fit(Z_train,Y_train)
# Out:
# LogisticRegression()

# %%
Z_train_prediction=model.predict(Z_train)
training_data_acuuracy=accuracy_score(Z_train_prediction,Y_train)

# %%
Z_test_prediction=model.predict(Z_test)
test_data_accuracy=accuracy_score(Z_test_prediction,Y_test)

# %%
print("Training dat accuracy:",training_data_acuuracy)
print("Test data accuracy:",test_data_accuracy)
# Out:
# Training dat accuracy: 0.9257975635538149
# Test data accuracy: 0.904276703403341

# %% [markdown]
# Prediction

# %%
Z_new=Z_test[0]

prediction=model.predict(Z_new)

print(prediction)

if(prediction==0):
  print("The news is fake")
else:
  print("The news is real")
# Out:
# [1]
# The news is real
